# %% [markdown]
# # Predict

# %%
import pandas as pd
import joblib
import lightgbm as lgb

# %%
# Load model
reg = joblib.load('model.joblib')
reg
# Out:
# LGBMRegressor(force_row_wise=True, verbose=0)

# %%
# Load data
df = pd.read_parquet('../data/gold/df.parquet')
df.head(3)
# Out:
#                      24h_later_load  year  month  day  hour  weekday  \
# datetime
# 2015-01-08 00:00:00            7299  2015      1    8     0        3
# 2015-01-08 01:00:00            6999  2015      1    8     1        3
# 2015-01-08 02:00:00            6864  2015      1    8     2        3
#
#                      1h_ago_load  2h_ago_load  3h_ago_load  24h_ago_load  \
# datetime
# 2015-01-08 00:00:00       8000.0       8212.0       8568.0        7722.0
# 2015-01-08 01:00:00       7605.0       8000.0       8212.0        7528.0
# 2015-01-08 02:00:00       7499.0       7605.0       8000.0        7510.0
#
#                      7d_ago_load  8h_min  8h_max  8h_median  24h_min  24h_max  \
# datetime
# 2015-01-08 00:00:00       7673.0  7605.0  9361.0     8695.0   7347.0   9447.0
# 2015-01-08 01:00:00       7633.0  7499.0  9361.0     8568.0   7347.0   9447.0
# 2015-01-08 02:00:00       7654.0  7423.0  9361.0     8212.0   7347.0   9447.0
#
# ...

# %%
# Run predictions
# TODO
